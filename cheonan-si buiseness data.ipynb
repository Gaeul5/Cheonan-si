# %% [markdown]
# 기업 수 - 경제활동인구 - 취업자 수 - 청년고용률 - 각종 기업 현황 - cf) 전통시장 현황

# %% [markdown]
# ## 천안시 기업 수 변화 현황

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
comsum = pd.read_csv('기업수.csv',encoding='cp949') #천안시 2019-2020 기업수 데이터 불러오기

# %%
comsum = comsum.set_index('연도')
comsum
# Out:
#           합계    소상공인    소기업   중기업    중소기업  대기업
# 연도
# 2019  277155  260385  13204  3239  276828  327
# 2020  294870  278066  13040  3408  294514  356

# %%
comsum.T.plot(kind='bar')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54633 (\N{HANGUL SYLLABLE HAB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
woman = pd.read_csv('여성경영인.csv',encoding='949') #천안시 여성경영인 기업수 데이터 불러오기

# %%
woman
# Out:
#      연도      전체    소상공인   소기업  중기업    중소기업  대기업
# 0  2015  178542   86128  2805  338   89271    0
# 1  2016   93196   89962  2872  359   93193    3
# 2  2017  196604   94928  2966  408   98302    0
# 3  2018  105086  101490  3174  419  105083    3
# 4  2019  109344  105729  3180  432  109341    3
# 5  2020  117061  113466  3134  454  117054    7

# %%
woman = woman.set_index('연도')
woman
# Out:
#           전체    소상공인   소기업  중기업    중소기업  대기업
# 연도
# 2015  178542   86128  2805  338   89271    0
# 2016   93196   89962  2872  359   93193    3
# 2017  196604   94928  2966  408   98302    0
# 2018  105086  101490  3174  419  105083    3
# 2019  109344  105729  3180  432  109341    3
# 2020  117061  113466  3134  454  117054    7

# %%
plt.figure(figsize=(12, 12))
woman.plot(marker='.')
plt.show()

# %%
plt.figure(figsize=(12, 12))
woman.plot(kind='bar')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ##천안시 경제활동인구 변화 현황

# %%
economy = pd.read_csv('경제활동인구.csv',encoding='cp949') #천안시 경제활동인구 데이터 불러오기

# %%
economy = economy.set_index('연도')
economy
# Out:
#               계     남자     여자
# 연도
# 2013.1/2  300.7  185.9  114.8
# 2013.2/2  304.6  190.7  113.9
# 2014.1/2  313.3  195.2  118.1
# 2014.2/2  316.2  193.0  123.2
# 2015.1/2  322.9  197.8  125.1
# 2015.2/2  319.9  199.1  120.8
# 2016.1/2  326.5  201.1  125.4
# 2016.2/2  330.0  207.1  122.9
# 2017.1/2  344.7  212.4  132.3
# 2017.2/2  356.0  216.6  139.4
# 2018.1/2  357.5  220.1  137.4
# 2018.2/2  374.0  228.7  145.3
# 2019.1/2  384.3  231.4  153.0
# 2019.2/2  384.7  230.8  153.9
# 2020.1/2  386.1  231.6  154.5
# 2020.2/2  389.7  232.5  157.1
# 2021.1/2  380.5  231.4  149.1
# 2021.2/2  387.1  234.6  152.5
# 2022.1/2  385.4  233.2  152.2
# 2022.2/2  394.1  234.5  159.7

# %%
plt.figure(figsize=(12, 12))
economy.plot(marker='.')
plt.show() #주황 : 남자 / 초록 : 여자
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ##천안시 취업자수 변화 현황

# %%
work = pd.read_csv('취업자수.csv',encoding='cp949') #천안시 취업자수 데이터 불러오기
work = work.set_index('연도')
work
# Out:
#               계     남자     여자
# 연도
# 2013.1/2  294.1  181.4  112.7
# 2013.2/2  297.3  185.8  111.5
# 2014.1/2  302.6  187.7  114.9
# 2014.2/2  308.7  188.2  120.6
# 2015.1/2  312.3  191.1  121.2
# 2015.2/2  310.3  194.5  115.8
# 2016.1/2  314.6  195.0  119.6
# 2016.2/2  320.6  200.6  120.0
# 2017.1/2  335.4  206.7  128.7
# 2017.2/2  345.7  211.1  134.6
# 2018.1/2  346.0  212.4  133.6
# 2018.2/2  362.2  221.4  140.9
# 2019.1/2  372.5  225.1  147.5
# 2019.2/2  376.0  226.3  149.7
# 2020.1/2  371.5  223.7  147.8
# 2020.2/2  377.3  226.0  151.3
# 2021.1/2  371.2  226.0  145.2
# 2021.2/2  377.7  229.3  148.5
# 2022.1/2  378.4  229.0  149.4
# 2022.2/2  385.0  229.7  155.3

# %%
plt.figure(figsize=(12, 12))
work.plot(marker='.')
plt.show() #주황 : 남자 / 초록 : 여자
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ##천안시 청년고용률 변화 현황 (15-29세)

# %%
boy = pd.read_csv('청년고용률.csv',encoding='cp949') #천안시 청년고용률 데이터 불러오기
boy = boy.set_index('연도')
boy
# Out:
#           청년고용률
# 연도
# 2013.1/2   39.5
# 2013.2/2   34.6
# 2014.1/2   38.1
# 2014.2/2   37.4
# 2015.1/2   37.8
# 2015.2/2   35.6
# 2016.1/2   35.0
# 2016.2/2   34.2
# 2017.1/2   36.6
# 2017.2/2   41.1
# 2018.1/2   39.8
# 2018.2/2   42.4
# 2019.1/2   46.9
# 2019.2/2   47.1
# 2020.1/2   43.6
# 2020.2/2   45.4
# 2021.1/2   43.2
# 2021.2/2   44.7
# 2022.1/2   44.9
# 2022.2/2   46.9

# %%
plt.figure(figsize=(12, 12))
boy.plot(marker='.')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47456 (\N{HANGUL SYLLABLE RYUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ##천안시 각종 기업 현황

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 36.1 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.4.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 36.6 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.3)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %%
import pandas as pd
from konlpy.tag import Komoran
from collections import Counter

# %%
#산업단지 기업 현황 (2022/6 기준)
ind = pd.read_csv('산업단지.csv',encoding='cp949') #천안시 산업단지 기업 데이터 불러오기
ind
# Out:
#               단지명           회사명                                   공장대표주소(도로명)  \
# 0    천안산업기술일반산업단지       주식회사 두코     충청남도 천안시 서북구 직산읍 직산로 136, 생산관 2105호 (직산읍)
# 1      천안마정일반산업단지    (주)케이와이컴퍼니                    충청남도 천안시 서북구 직산읍 금곡로 52-20
# 2    천안산업기술일반산업단지      주식회사 바이콘           충청남도 천안시 서북구 직산읍 직산로 136, 생산관 2305호
# 3    천안산업기술일반산업단지       (주)인피닉스    충청남도 천안시 서북구 직산읍 직산로 136, 충남테크노파크 영상관 506호
# 4    천안산업기술일반산업단지      (주)에스피에스  충청남도 천안시 서북구 직산읍 직산로 136, 3102호(충남테크노파크 생산관)
# ..            ...           ...                                           ...
# 964    천안풍세일반산업단지  (주)에이치케이피앤에스                     충청남도 천안시 동남구 풍세면 풍세산단로 50
# 965    천안풍세일반산업단지     주식회사 유엔아이            충청남도 천안시 동남구 풍세면 풍세산단3로 20, 2동, 3동
# 966    천안풍세일반산업단지         오트밀식품                    충청남도 천안시 동남구 풍세면 용정리 993번지
# 967    천안풍세일반산업단지    주식회사 세원이엔지                  충청남도 천안시 동남구 풍세면 풍세산단로 226-8
# 968    천안풍세일반산업단지     (주)디와이이엔지                    충청남도 천안시 동남구 풍세면 풍세산단1로 35
#
#               전화번호
# 0        1644-3880
# 1        1599-3176
# 2        1566-7185
# 3        1688-0201
# 4    070-8871-5835
# ..             ...
# 964            NaN
# 965            NaN
# 966            NaN
# 967            NaN
# 968            NaN
#
# [969 rows x 4 columns]

# %%
ind['단지명'].value_counts() #천안제3일반산업단지에 가장 많은 기업이 위치하고 있다.
# Out:
# 천안제3일반산업단지      185
# 천안산업기술일반산업단지    128
# 천안제4일반산업단지      125
# 천안백석농공단지        119
# 천안풍세일반산업단지      100
# 천안제2일반산업단지       80
# 천안마정일반산업단지       63
# 천안제5일반산업단지       54
# 천안직산농공단지         41
# 천안외국인투자지역        35
# 천안천흥일반산업단지       19
# 천안5산단외국인투자지역     13
# 천안동면농공단지          4
# 천안목천농공단지          3
# Name: 단지명, dtype: int64

# %%
# 형태소 분석기를 사용하여 '회사명'에서 명사 형태소를 추출합니다.
komoran = Komoran()
words = ind['회사명'].apply(lambda x: [word for word, pos in komoran.pos(x) if pos == 'NNG' and len(word) > 1])

# 불용어(stopwords) 리스트를 정의합니다.
stopwords = ['주식회사', '(주)', '영상관', '생산관', '생산', '공장대표주소']

# 불용어와 한 글자를 제외하고 가장 많이 나온 단어를 찾습니다.
filtered_words = [word for sublist in words for word in sublist if word not in stopwords]
most_common_words = Counter(filtered_words).most_common()

print(most_common_words)
# Out:
# [('테크', 59), ('시스템', 14), ('에이', 13), ('엔지니어링', 13), ('테크놀로지', 8), ('푸드', 5), ('코스', 4), ('대상', 4), ('컴퍼니', 3), ('하이테크', 3), ('물산', 3), ('성원', 3), ('기업', 3), ('나래', 3), ('식품', 3), ('아이', 3), ('동원', 2), ('오토메이션', 2), ('일광', 2), ('한울', 2), ('소재', 2), ('상상', 2), ('포토', 2), ('엑스', 2), ('동일', 2), ('산업', 2), ('태성', 2), ('쓰리', 2), ('명문', 2), ('열기', 2), ('다원', 2), ('사업장', 2), ('중오', 2), ('사회', 1), ('보호', 1), ('작업장', 1), ('미디어', 1), ('삼현', 1), ('선명', 1), ('컨덕터', 1), ('아트', 1), ('구비', 1), ('아인스', 1), ('연합', 1), ('씨티', 1), ('정형', 1), ('제일', 1), ('부흥', 1), ('메리트', 1), ('영상', 1), ('웅비', 1), ('견지', 1), ('지일', 1), ('금환', 1), ('쎄븐', 1), ('나이', 1), ('삼우', 1), ('상승', 1), ('자평', 1), ('사무기기', 1), ('농기', 1), ('축산물', 1), ('공판장', 1), ('폴리머', 1), ('알티', 1), ('사무소', 1), ('대아', 1), ('환경', 1), ('특장', 1), ('기사', 1), ('청실', 1), ('홍실', 1), ('토스', 1), ('판금', 1), ('방주', 1), ('노무', 1), ('컨설팅', 1), ('콘트롤', 1), ('전원', 1), ('대신', 1), ('스냅', 1), ('오병이어', 1), ('태양광', 1), ('창성', 1), ('엑시', 1), ('이데아', 1), ('무역', 1), ('수경', 1), ('통상', 1), ('우인', 1), ('건강식품', 1), ('기획', 1), ('인사', 1)]

# %%
#제조업체 현황 (2022/9 기준)
make = pd.read_csv('제조업체.csv',encoding='cp949') #천안시 제조업체 기업 데이터 불러오기
make
# Out:
#                 업종명       기업체명  \
# 0     고무제품 및 플라스틱제품  (주)동아수지산업
# 1              기타제품      KY컴퍼니
# 2         기타기계 및 장비     N&P시스템
# 3              기타제품      RP이엔지
# 4     고무제품 및 플라스틱제품       남주테크
# ...             ...        ...
# 3186         비금속광물제  휴먼이엔티주식회사
# 3187            식료품       흥림농산
# 3188   인쇄 및 기록매체복제업   희성폴리머(주)
# 3189      기타기계 및 장비         희영
# 3190      기타기계 및 장비     히트텍(주)
#
#                                                     소재지  \
# 0                             충청남도 천안시 서북구 직산읍 금곡로 52-5
# 1                            충청남도 천안시 서북구 직산읍 금곡로 52-20
# 2                            충청남도 천안시 서북구 직산읍 금곡로 52-11
# 3                               충청남도 천안시 서북구 직산읍 금곡로 57
# 4                               충청남도 천안시 서북구 직산읍 금곡로 45
# ...                                                 ...
# 3186                         충청남도 천안시 서북구 성거읍 망향로 903-6
# 3187                       충청남도 천안시 동남구 수신면 장산동길 168-27
# 3188             충청남도 천안시 서북구 성환읍 천안대로 2131 (성환읍) 외 1필지
# 3189  충청남도 천안시 서북구 직산읍 금곡로 141 ((주)그린테크산업) (총 3 필지) ...
# 3190                          충청남도 천안시서북구 직산읍 마정리 522번지
#
#                         주생산품           전화번호
# 0              플리스틱 및 절연제품가공   041-417-7801
# 1                        마스크      1599-3176
# 2                      자동화기기  070-4352-4760
# 3                    특수구조물제작            NaN
# 4                     기타부품제작            NaN
# ...                      ...            ...
# 3186  패널,인방제,바닥제구조물, 디자인형울타리   041-622-0118
# 3187               참기름,압착식용유            NaN
# 3188           포장재, 광고지, 천막지   041-559-1000
# 3189                   금형제조업   041-583-1677
# 3190               차량공조 열교환기   041-584-8881
#
# [3191 rows x 5 columns]

# %%
make['업종명'].value_counts() #기타가 가장 많고, 그 이후로는 금속가공제품과 고무 및 플라스틱 / 전기 장비 / 식료품 순으로 많다.
# Out:
# 기타기계 및 장비                   723
# 금속가공제품(기계 및 가구제외)           371
# 고무제품 및 플라스틱제품               280
# 전기장비                        280
# 식료품                         274
# 전자부품, 컴퓨터, 영상, 음향 및 통신장비    223
# 화학물질 및 화학제품:의약품제외           215
# 자동차 및 트레일러                  173
# 의료, 정밀, 광학기기 및 시계           104
# 비금속광물제                       97
# 섬유제품                         89
# 펄프,종이 및 종이제품                 75
# 기타제품                         49
# 목재 및 나무제품(가구제외)              44
# 의료용물질 및 의약품                  43
# 1차금속                         38
# 인쇄 및 기록매체복제업                 31
# 가구                           26
# 산업용 기계 및 장비수리업               17
# 기타운송장비                       14
# 음료                           11
# 의복,의복액세서리 및 모피제품             11
# 코크스, 연탄 및 석유정제품               2
# Name: 업종명, dtype: int64

# %%
make['주생산품'].value_counts() #자동차부품을 생산하는 제조업체가 가장 많고, 그 이후로는 마스크, 화장품 등이 가장 많다.
# Out:
# 자동차부품                            37
# 마스크                              20
# 화장품                              19
# 철구조물                             12
# 골판지상자                            12
#                                  ..
# 액체연료여과기 등                         1
# 미끄럼방지제                            1
# 전동기(DC모터)                         1
# PDP X.Y,CERAMIC TRIMMER,습도센서기     1
# 차량공조 열교환기                         1
# Name: 주생산품, Length: 2798, dtype: int64

# %%
# 형태소 분석기를 사용하여 '기업체명'에서 명사 형태소를 추출합니다.
komoran = Komoran()
words = make['기업체명'].apply(lambda x: [word for word, pos in komoran.pos(x) if pos == 'NNG' and len(word) > 1])

# 불용어(stopwords) 리스트를 정의합니다.
stopwords = ['주식회사', '(주)', '영상관', '생산관', '생산', '공장대표주소']

# 불용어와 한 글자를 제외하고 가장 많이 나온 단어를 찾습니다.
filtered_words = [word for sublist in words for word in sublist if word not in stopwords]
most_common_words = Counter(filtered_words).most_common()

print(most_common_words)
# Out:
# [('테크', 199), ('엔지니어링', 43), ('식품', 31), ('에이', 30), ('푸드', 27), ('시스템', 26), ('기업', 20), ('산업', 20), ('테크놀로지', 14), ('종합', 12), ('하이테크', 9), ('코스', 9), ('농사', 9), ('특장', 9), ('아이', 8), ('태성', 8), ('동일', 7), ('프라스틱', 7), ('소재', 7), ('복지회', 6), ('다원', 6), ('물산', 6), ('컴퍼니', 5), ('사업단', 5), ('사업장', 5), ('중기', 5), ('철강', 5), ('제일', 5), ('선영', 4), ('선진', 4), ('쓰리', 4), ('무역', 4), ('비젼', 4), ('엑스', 4), ('해성', 4), ('나래', 4), ('대상', 4), ('사회', 4), ('한마음', 3), ('대아', 3), ('아트', 3), ('아우', 3), ('삼일', 3), ('농기계', 3), ('씨티', 3), ('신소재', 3), ('통상', 3), ('포토', 3), ('한길', 3), ('금형', 3), ('세라믹', 3), ('성원', 3), ('영농', 3), ('신진', 3), ('우인', 3), ('콘트롤', 2), ('라이팅', 2), ('글라스', 2), ('마루', 2), ('명문', 2), ('상신', 2), ('송림', 2), ('쎄븐', 2), ('공장', 2), ('아인스', 2), ('운영', 2), ('노스', 2), ('일광', 2), ('창성', 2), ('대리석', 2), ('오토메이션', 2), ('한울', 2), ('진메', 2), ('국제', 2), ('나라', 2), ('미곡', 2), ('처리장', 2), ('대신', 2), ('자재', 2), ('동원', 2), ('냉동', 2), ('방주', 2), ('재단', 2), ('농기', 2), ('상상', 2), ('판지', 2), ('시대', 2), ('수산', 2), ('일성', 2), ('일신', 2), ('열기', 2), ('입장', 2), ('제기', 2), ('폴리머', 2), ('천광', 2), ('공동', 2), ('명산업', 1), ('행복', 1), ('장애인', 1), ('화장지', 1), ('스토리', 1), ('지기', 1), ('견지', 1), ('골든', 1), ('관수', 1), ('교강', 1), ('구비', 1), ('로컬', 1), ('코팅', 1), ('산판', 1), ('정보통신', 1), ('대승', 1), ('프론티어', 1), ('대풍', 1), ('협회', 1), ('냉기', 1), ('멘스', 1), ('만호', 1), ('모터', 1), ('모두', 1), ('못난이', 1), ('미모', 1), ('부흥', 1), ('사우스', 1), ('상승', 1), ('전원', 1), ('선제', 1), ('경량', 1), ('세인', 1), ('스냅', 1), ('알티', 1), ('웨이', 1), ('엑시', 1), ('철판', 1), ('제어', 1), ('기술', 1), ('웅비', 1), ('기획', 1), ('율사', 1), ('이데아', 1), ('이체', 1), ('정형', 1), ('세상', 1), ('밥상', 1), ('지일', 1), ('창세', 1), ('창해', 1), ('천신', 1), ('철망', 1), ('청솔', 1), ('충일', 1), ('기우', 1), ('알미늄', 1), ('토스', 1), ('토담', 1), ('패커드', 1), ('미디어', 1), ('향토', 1), ('유전자원', 1), ('공감', 1), ('농공', 1), ('현세', 1), ('월드', 1), ('환경', 1), ('경기', 1), ('국민', 1), ('흑판', 1), ('국영', 1), ('금원', 1), ('금환', 1), ('지킴이', 1), ('남도', 1), ('내일', 1), ('목인', 1), ('진담', 1), ('도모', 1), ('실험실', 1), ('대륙', 1), ('양계', 1), ('축산물', 1), ('공판장', 1), ('대주', 1), ('룩스', 1), ('센타', 1), ('동남', 1), ('동보', 1), ('동성', 1), ('믹스', 1), ('타전', 1), ('매일', 1), ('메이드', 1), ('명지', 1), ('문화', 1), ('개정', 1), ('번창', 1), ('보람', 1), ('부국', 1), ('사예', 1), ('보호', 1), ('작업장', 1), ('삼강', 1), ('삼우', 1), ('싸이클', 1), ('삼현', 1), ('공영', 1), ('서화', 1), ('지점', 1), ('성가', 1), ('김치', 1), ('성형', 1), ('흥업', 1), ('세계', 1), ('세기', 1), ('소문', 1), ('송죽', 1), ('수경', 1), ('수용', 1), ('식탁', 1), ('일상사', 1), ('사이언티픽', 1), ('여송', 1), ('연성', 1), ('연합', 1), ('영상', 1), ('영화', 1), ('시트', 1), ('합성', 1), ('샤시', 1), ('우민', 1), ('우방', 1), ('은수', 1), ('인사', 1), ('일심', 1), ('공예사', 1), ('자경', 1), ('자담', 1), ('자원', 1), ('자생', 1), ('자평', 1), ('판금', 1), ('정도', 1), ('산기', 1), ('정일', 1), ('제세', 1), ('지상', 1), ('기사', 1), ('나이', 1), ('메디컬', 1), ('비씨', 1), ('선명', 1), ('프라자', 1), ('애드', 1), ('은성', 1), ('은혜', 1), ('안전', 1), ('청산', 1), ('호명', 1), ('중오', 1), ('천공', 1), ('본부', 1), ('실업', 1), ('청실', 1), ('홍실', 1), ('비니루', 1), ('충의', 1), ('써비스', 1), ('비티', 1), ('건강식품', 1), ('하늘', 1), ('서비스', 1), ('행운', 1), ('방제', 1), ('중장비', 1), ('현신', 1), ('화창', 1)]

# %%
#공중위생업소 현황 (2022/9 기준)
san = pd.read_csv('공중위생업소.csv',encoding='cp949') #천안시 공중위생업소 데이터 불러오기
san
# Out:
#                        위생업소구분      업소명                             소재지도로명주소  \
# 0                     숙박업(일반)     동궁여관  충청남도 천안시 서북구 성환읍 성환2로 134, 동궁장 2,3층
# 1                     숙박업(일반)  한양파크장여관           충청남도 천안시 서북구 봉정로 103 (성정동)
# 2                     숙박업(일반)     이화모텔            충청남도 천안시 서북구 차돌로 10 (쌍용동)
# 3                     숙박업(일반)    성거여인숙             충청남도 천안시 서북구 성거읍 성거길 129
# 4                     숙박업(일반)     금관여관             충청남도 천안시 서북구 입장면 입장로 144
# ...                       ...      ...                                  ...
# 2668  피부미용업, 네일미용업, 화장ㆍ분장 미용업      반하다  충청남도 천안시 동남구 풍세로 798, 1층 105호 (청당동)
# 2669  피부미용업, 네일미용업, 화장ㆍ분장 미용업    하늘연네일       충청남도 천안시 동남구 터미널6길 9, 1층 (신부동)
# 2670  피부미용업, 네일미용업, 화장ㆍ분장 미용업   제이와이뷰티       충청남도 천안시 동남구 통정8로 17, 1층 (신방동)
# 2671  피부미용업, 네일미용업, 화장ㆍ분장 미용업     더더네일       충청남도 천안시 동남구 중앙로 213, 1층 (신부동)
# 2672  피부미용업, 네일미용업, 화장ㆍ분장 미용업     주니네일      충청남도 천안시 동남구 목천읍 서리1길 54-10, 1층
#
#                               소재지지번주소          전화번호
# 0     충청남도 천안시 서북구 성환읍 성환리 280-8 동궁장   041-581-9191
# 1             충청남도 천안시 서북구 성정동 743-5   041-574-2002
# 2             충청남도 천안시 서북구 쌍용동 533-5   041-572-7033
# 3           충청남도 천안시 서북구 성거읍 저리 52-3   041-622-0785
# 4            충청남도 천안시 서북구 입장면 하장리 63   041-583-5135
# ...                               ...           ...
# 2668         충청남도 천안시 동남구 청당동 396-12            NaN
# 2669         충청남도 천안시 동남구 신부동 804 1층            NaN
# 2670           충청남도 천안시 동남구 신방동 1385            NaN
# 2671      충청남도 천안시 동남구 신부동 371-25 1층            NaN
# 2672    충청남도 천안시 동남구 목천읍 서리 24-10 1층            NaN
#
# [2673 rows x 5 columns]

# %%
san['위생업소구분'].value_counts() #일반미용업이 가장 많고, 그 이후로 피부, 숙박, 네일, 미용이 많다.
# Out:
# 일반미용업                      1197
# 피부미용업                       321
# 숙박업(일반)                     316
# 네일미용업                       228
# 미용업                         122
# 종합미용업                       112
# 일반미용업, 화장ㆍ분장 미용업             82
# 피부미용업, 네일미용업                 60
# 화장ㆍ분장 미용업                    55
# 네일미용업, 화장ㆍ분장 미용업             41
# 피부미용업, 네일미용업, 화장ㆍ분장 미용업      38
# 피부미용업, 화장ㆍ분장 미용업             32
# 일반미용업, 네일미용업                 23
# 일반미용업, 네일미용업, 화장ㆍ분장 미용업      16
# 일반미용업, 피부미용업                 15
# 숙박업(생활)                       9
# 일반미용업, 피부미용업, 화장ㆍ분장 미용업       4
# 일반미용업, 피부미용업, 네일미용업           2
# Name: 위생업소구분, dtype: int64

# %%
# 형태소 분석기를 사용하여 '업소명'에서 명사 형태소를 추출합니다.
komoran = Komoran()
words = san['업소명'].apply(lambda x: [word for word, pos in komoran.pos(x) if pos == 'NNG' and len(word) > 1])

# 한 글자를 제외하고 가장 많이 나온 단어를 찾습니다.
filtered_words = [word for sublist in words for word in sublist if word not in stopwords and len(word) > 1]
most_common_words = Counter(filtered_words).most_common()

print(most_common_words)
# Out:
# [('헤어', 744), ('스킨케어', 28), ('머리', 21), ('아트', 17), ('오늘', 13), ('메이크업', 13), ('테크', 12), ('사랑', 10), ('아이', 8), ('남성', 8), ('커트', 8), ('미용', 7), ('호텔', 6), ('하루', 6), ('언니', 6), ('관리실', 6), ('정점', 5), ('그날', 5), ('남자', 4), ('미장원', 4), ('공감', 4), ('신불', 4), ('에이', 4), ('메이드', 4), ('마이', 3), ('프로', 3), ('무드', 3), ('포유', 3), ('바이', 3), ('관광호텔', 2), ('비지니스', 2), ('명품', 2), ('창조', 2), ('코디', 2), ('버르장머리', 2), ('메종드', 2), ('단장', 2), ('쓰리', 2), ('모던', 2), ('천연', 2), ('나래', 2), ('핸섬', 2), ('전문', 2), ('제니', 2), ('차밍', 2), ('미용실', 2), ('은빛', 2), ('스킨', 2), ('체형', 2), ('주의', 2), ('황실', 2), ('예인', 2), ('골든', 2), ('행복', 2), ('하자', 2), ('낭만', 2), ('꾸밈', 2), ('성장', 2), ('키즈', 2), ('국빈', 2), ('로얄', 1), ('삼일', 1), ('강변', 1), ('씨티', 1), ('스프', 1), ('프리마', 1), ('구구', 1), ('블럭', 1), ('쎄븐', 1), ('꽁지', 1), ('꽃샘', 1), ('프라자', 1), ('모레', 1), ('새내기', 1), ('수연', 1), ('플러스', 1), ('클럽', 1), ('사람', 1), ('나라', 1), ('진실', 1), ('매니아', 1), ('이야기', 1), ('클리닉', 1), ('지연', 1), ('프리티', 1), ('골목', 1), ('신주', 1), ('은수', 1), ('미감', 1), ('수요', 1), ('스리', 1), ('송경', 1), ('핸썸', 1), ('빌리지', 1), ('정감', 1), ('손길', 1), ('단발', 1), ('다감', 1), ('오브', 1), ('데생', 1), ('디자인', 1), ('이날', 1), ('순간', 1), ('차이', 1), ('시연', 1), ('남쪽', 1), ('기억', 1), ('지금', 1), ('향기', 1), ('세안', 1), ('여왕', 1), ('정성', 1), ('나무', 1), ('비밀', 1), ('스파', 1), ('더하기', 1), ('눈썰미', 1), ('슈슈', 1), ('예스', 1), ('낯빛', 1), ('자연', 1), ('토탈', 1), ('센타', 1), ('개인', 1), ('취향', 1), ('미스', 1), ('피부', 1), ('미모', 1), ('붙임', 1), ('공방', 1), ('눈썹', 1), ('포즈', 1), ('셀러', 1), ('휴대폰', 1), ('나도', 1), ('발톱', 1), ('손끝', 1), ('여시', 1), ('모이', 1), ('이제', 1), ('유리', 1), ('드레', 1), ('작업실', 1), ('최강', 1), ('동안', 1), ('성성', 1), ('피케이', 1), ('드로잉', 1), ('모퉁이', 1), ('손톱', 1), ('신래', 1), ('도화', 1), ('벨브', 1), ('연장', 1), ('선생', 1), ('살롱', 1), ('눈빛', 1), ('앵두', 1), ('코지', 1), ('애프터', 1), ('제시', 1), ('버들', 1), ('동남', 1), ('미화', 1), ('일심', 1), ('으뜸', 1), ('별장', 1), ('풍장', 1), ('해성', 1), ('행운', 1), ('휴일', 1), ('드라이브', 1), ('피스', 1), ('준비', 1), ('제일', 1), ('여정', 1), ('최신', 1), ('미래', 1), ('오토바이', 1), ('세대교체', 1), ('남향', 1), ('금실', 1), ('청솔', 1), ('동네', 1), ('불로', 1), ('구내', 1), ('애드', 1), ('은혜', 1), ('참빗', 1), ('유재', 1), ('컨셉', 1), ('다보', 1), ('천사', 1), ('품격', 1), ('가득', 1), ('디테일', 1), ('하늘', 1), ('순수', 1), ('까까', 1), ('부탁', 1), ('콘티', 1), ('엄지', 1), ('영선', 1), ('오케이', 1), ('편집실', 1), ('소유', 1), ('이유', 1), ('내츄럴', 1), ('변신', 1), ('모당', 1), ('공간', 1), ('여우', 1), ('세상', 1), ('누이', 1)]
